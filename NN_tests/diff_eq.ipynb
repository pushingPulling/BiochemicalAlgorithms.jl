# %% [markdown]
# Diff Eq:
#     - is a Eq involving unknown eq y = f(x) and its derivatives. E.g. y' = 3x^2
#     - the solution to a DE is finding y. e.g. y = 6x^3
#     - order = highest order deriv in eq
#     - general sol: eq of form y = f(x) + C.   The constant C dies when this func is derived
#     - initial value prob: have as many initial conditions y(x) = v_1 as the order of diff eq
#     - verify sol to intial val prob: verify that eq and initial conditions are satisfied
#     -
