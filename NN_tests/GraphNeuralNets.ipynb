# %%
import Pkg
Pkg.add("Flux")
# Out:
#    Resolving package versions...
# Unsatisfiable requirements detected for package GPUCompiler [61eb1bfa]:
#
#  GPUCompiler [61eb1bfa] log:
#
#  ├─possible versions are: 0.1.0-0.26.5 or uninstalled
#
#  ├─restricted by compatibility requirements with DataStructures [864edb3b] to versions: [0.6.1, 0.7.1-0.26.5] or uninstalled
#
#  │ └─DataStructures [864edb3b] log:
#
#  │   ├─possible versions are: 0.9.0-0.18.20 or uninstalled
#
#  │   └─restricted to versions 0.18 by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.18.0-0.18.20
#
#  │     └─BiochemicalAlgorithms [9d651bdf] log:
#
#  │       ├─possible versions are: 0.1.0 or uninstalled
#
#  │       └─BiochemicalAlgorithms [9d651bdf] is fixed to version 0.1.0
#
#  ├─restricted by julia compatibility requirements to versions: 0.22.0-0.26.5 or uninstalled
#
#  ├─restricted by compatibility requirements with Enzyme [7da242da] to versions: [0.4.0-0.4.1, 0.7.0-0.17.3, 0.19.0-0.26.5], leaving only versions: 0.22.0-0.26.5
#
#  │ └─Enzyme [7da242da] log:
#
#  │   ├─possible versions are: 0.1.0-0.12.9 or uninstalled
#
#  │   └─restricted to versions * by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.1.0-0.12.9
#
#  │     └─BiochemicalAlgorithms [9d651bdf] log: see above
#
#  ├─restricted by compatibility requirements with CUDA [052768ef] to versions: [0.11.1-0.12.9, 0.13.3-0.21.4, 0.24.0-0.26.5], leaving only versions: 0.24.0-0.26.5
#
#  │ └─CUDA [052768ef] log:
#
#  │   ├─possible versions are: 0.1.0-5.4.2 or uninstalled
#
#  │   ├─restricted to versions * by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.1.0-5.4.2
#
#  │   │ └─BiochemicalAlgorithms [9d651bdf] log: see above
#
#  │   ├─restricted by compatibility requirements with DataStructures [864edb3b] to versions: 1.3.3-5.4.2 or uninstalled, leaving only versions: 1.3.3-5.4.2
#
#  │   │ └─DataStructures [864edb3b] log: see above
#
#  │   ├─restricted by compatibility requirements with NeuralOperators [ea5c82af] to versions: 3.0.0-5.4.2
#
#  │   │ └─NeuralOperators [ea5c82af] log:
#
#  │   │   ├─possible versions are: 0.1.0-0.4.8 or uninstalled
#
#  │   │   ├─restricted to versions * by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.1.0-0.4.8
#
#  │   │   │ └─BiochemicalAlgorithms [9d651bdf] log: see above
#
#  │   │   └─restricted by compatibility requirements with Flux [587475ba] to versions: 0.3.2-0.4.8 or uninstalled, leaving only versions: 0.3.2-0.4.8
#
#  │   │     └─Flux [587475ba] log:
#
#  │   │       ├─possible versions are: 0.4.1-0.14.15 or uninstalled
#
#  │   │       ├─restricted to versions * by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.4.1-0.14.15
#
#  │   │       │ └─BiochemicalAlgorithms [9d651bdf] log: see above
#
#  │   │       └─restricted to versions 0.13.17 by an explicit requirement, leaving only versions: 0.13.17
#
#  │   ├─restricted by compatibility requirements with Flux [587475ba] to versions: 3.0.0-4.4.2
#
#  │   │ └─Flux [587475ba] log: see above
#
#  │   └─restricted by compatibility requirements with GraphNeuralNetworks [cffab07f] to versions: 3.3.0-4.4.2
#
#  │     └─GraphNeuralNetworks [cffab07f] log:
#
#  │       ├─possible versions are: 0.1.0-0.6.19 or uninstalled
#
#  │       ├─restricted to versions * by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.1.0-0.6.19
#
#  │       │ └─BiochemicalAlgorithms [9d651bdf] log: see above
#
#  │       ├─restricted by compatibility requirements with StatsBase [2913bbd2] to versions: 0.1.0-0.6.7 or uninstalled, leaving only versions: 0.1.0-0.6.7
#
#  │       │ └─StatsBase [2913bbd2] log:
#
#  │       │   ├─possible versions are: 0.24.0-0.34.3 or uninstalled
#
#  │       │   ├─restricted to versions 0.33 by BiochemicalAlgorithms [9d651bdf], leaving only versions: 0.33.0-0.33.21
#
#  │       │   │ └─BiochemicalAlgorithms [9d651bdf] log: see above
#
#  │       │   └─restricted by compatibility requirements with DataStructures [864edb3b] to versions: 0.33.1-0.34.3 or uninstalled, leaving only versions: 0.33.1-0.33.21
#
#  │       │     └─DataStructures [864edb3b] log: see above
#
#  │       └─restricted by compatibility requirements with Flux [587475ba] to versions: 0.4.0-0.6.7 or uninstalled, leaving only versions: 0.4.0-0.6.7
#
#  │         └─Flux [587475ba] log: see above
#
#  └─restricted by compatibility requirements with CUDA [052768ef] to versions: [0.12.0-0.12.9, 0.13.3-0.21.4] — no versions left
#
#    └─CUDA [052768ef] log: see above
#
#
#
# Stacktrace:
#
#   [1] propagate_constraints!(graph::Pkg.Resolve.Graph, sources::Set{Int64}; log_events::Bool)
#
#     @ Pkg.Resolve C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Resolve\graphtype.jl:1072
#
#   [2] propagate_constraints! (repeats 2 times)
#
#     @ C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Resolve\graphtype.jl:1008 [inlined]
#
#   [3] simplify_graph!(graph::Pkg.Resolve.Graph, sources::Set{Int64}; clean_graph::Bool)
#
#     @ Pkg.Resolve C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Resolve\graphtype.jl:1533
#
#   [4] simplify_graph! (repeats 2 times)
#
#     @ C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Resolve\graphtype.jl:1532 [inlined]
#
#   [5] resolve_versions!(env::Pkg.Types.EnvCache, registries::Vector{Pkg.Registry.RegistryInstance}, pkgs::Vector{Pkg.Types.PackageSpec}, julia_version::VersionNumber, installed_only::Bool)
#
#     @ Pkg.Operations C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Operations.jl:408
#
#   [6] targeted_resolve(env::Pkg.Types.EnvCache, registries::Vector{Pkg.Registry.RegistryInstance}, pkgs::Vector{Pkg.Types.PackageSpec}, preserve::Pkg.Types.PreserveLevel, julia_version::VersionNumber)
#
#     @ Pkg.Operations C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Operations.jl:1361
#
#   [7] tiered_resolve(env::Pkg.Types.EnvCache, registries::Vector{Pkg.Registry.RegistryInstance}, pkgs::Vector{Pkg.Types.PackageSpec}, julia_version::VersionNumber, try_all_installed::Bool)
#
#     @ Pkg.Operations C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Operations.jl:1350
#
#   [8] _resolve(io::VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)}, env::Pkg.Types.EnvCache, registries::Vector{Pkg.Registry.RegistryInstance}, pkgs::Vector{Pkg.Types.PackageSpec}, preserve::Pkg.Types.PreserveLevel, julia_version::VersionNumber)
#
#     @ Pkg.Operations C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Operations.jl:1371
#
#   [9] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}, new_git::Set{Base.UUID}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform)
#
#     @ Pkg.Operations C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Operations.jl:1388
#
#  [10] add
#
#     @ C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Operations.jl:1377 [inlined]
#
#  [11] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, kwargs::@Kwargs{io::VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)}})
#
#     @ Pkg.API C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:278
#
#  [12] add(pkgs::Vector{Pkg.Types.PackageSpec}; io::VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)}, kwargs::@Kwargs{})
#
#     @ Pkg.API C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:159
#
#  [13] add(pkgs::Vector{Pkg.Types.PackageSpec})
#
#     @ Pkg.API C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:148
#
#  [14] add
#
#     @ C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:147 [inlined]
#
#  [15] add(pkg::String)
#
#     @ Pkg.API C:\Users\dan\.julia\juliaup\julia-1.10.3+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:146
#
#  [16] top-level scope
#
#     @ c:\Users\dan\BiochemicalAlgorithms.jl\NN_tests\GraphNeuralNets.ipynb:2

# %%
using Flux
using Flux: onecold, onehotbatch, logitcrossentropy
using MLDatasets
using LinearAlgebra, Random, Statistics
import GraphMakie
import CairoMakie as Makie
using Graphs
using GraphNeuralNetworks
ENV["DATADEPS_ALWAYS_ACCEPT"] = "true"  # don't ask for dataset download confirmation
Random.seed!(17); # for reproducibility
# Out:
# ArgumentError: Package Flux [587475ba-b771-5e3f-ad9e-33799f191a9c] is required but does not seem to be installed:
#
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
#
#
#
#
# Stacktrace:
#
#   [1] _require(pkg::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1926
#
#   [2] __require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1812
#
#   [3] #invoke_in_world#3
#
#     @ .\essentials.jl:926 [inlined]
#
#   [4] invoke_in_world
#
#     @ .\essentials.jl:923 [inlined]
#
#   [5] _require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1803
#
#   [6] macro expansion
#
#     @ .\loading.jl:1790 [inlined]
#
#   [7] macro expansion
#
#     @ .\lock.jl:267 [inlined]
#
#   [8] __require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1753
#
#   [9] #invoke_in_world#3
#
#     @ .\essentials.jl:926 [inlined]
#
#  [10] invoke_in_world
#
#     @ .\essentials.jl:923 [inlined]
#
#  [11] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1746
#
#  [12] eval
#
#     @ .\boot.jl:385 [inlined]
#
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2076
#
#  [14] #invokelatest#2
#
#     @ .\essentials.jl:892 [inlined]
#
#  [15] invokelatest
#
#     @ .\essentials.jl:889 [inlined]
#
#  [16] (::VSCodeServer.var"#219#220"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\dan\.vscode\extensions\julialang.language-julia-1.79.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:19
#
#  [17] withpath(f::VSCodeServer.var"#219#220"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\dan\.vscode\extensions\julialang.language-julia-1.79.2\scripts\packages\VSCodeServer\src\repl.jl:276
#
#  [18] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, params::VSCodeServer.NotebookRunCellArguments)
#
#     @ VSCodeServer c:\Users\dan\.vscode\extensions\julialang.language-julia-1.79.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [19] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::Dict{String, Any})
#
#     @ VSCodeServer.JSONRPC c:\Users\dan\.vscode\extensions\julialang.language-julia-1.79.2\scripts\packages\JSONRPC\src\typed.jl:67
#
#  [20] serve_notebook(pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; crashreporting_pipename::String)
#
#     @ VSCodeServer c:\Users\dan\.vscode\extensions\julialang.language-julia-1.79.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:139
#
#  [21] top-level scope
#
#     @ c:\Users\dan\.vscode\extensions\julialang.language-julia-1.79.2\scripts\notebook\notebook.jl:35
